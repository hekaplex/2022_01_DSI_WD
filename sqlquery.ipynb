-- %%
SELECT * FROM [CSInc].[vInvoiceHeader]
-- Out:
-- (845 rows affected)
-- Total execution time: 00:00:02.811
-- <table><tr><th>AccountNumber</th><th>InvoiceID</th><th>CustomerID</th><th>Company</th><th>Company Address</th><th>Company Phone</th><th>Company EMail</th><th>Invoice SubTotal</th><th>Tax Amount</th><th>Service Charge</th><th>Invoice Total</th><th>Invoice Date</th><th>Due Date</th><th>InvoiceStatus</th><th>DatePaid</th></tr><tr><td>10-4022-1</td><td>900008</td><td>1</td><td>A Machine Store</td><td>8713 Yosemite Ct.
-- Montgomery, Alabama, 36104
-- </td><td>367-555-0246</td><td>orlando0@adventure-works.com</td><td>2900.4</td><td>248.477268</td><td>435.06</td><td>3583.937268</td><td>02/17/2022</td><td>02/17/2022</td><td>Invoiced</td><td>NULL</td></tr><tr><td>10-4022-10</td><td>902850</td><td>10</td><td>Rural Machine Emporium</td><td>6388 Lake City Way
-- Dover, Delaware, 19901
-- ...
