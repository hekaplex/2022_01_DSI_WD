# %%
# !pip install pyodbc
# Out:
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\andre\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\andre\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\andre\anaconda3\lib\site-packages)
# WARNING: Error parsing requirements for google-pasta: [Errno 2] No such file or directory: 'c:\\users\\andre\\anaconda3\\lib\\site-packages\\google_pasta-0.2.0.dist-info\\METADATA'
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\andre\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\andre\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\andre\anaconda3\lib\site-packages)

# %%
import pyodbc
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=localhost;DATABASE=AdventureWorks2019;Trusted_Connection=yes')

# %%
import pyodbc
conn2 = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=divergencesqldsi202110.database.windows.net;DATABASE=test;UID=dsi202110;PWD=2021?10!DSI')

# %%
import pandas
sql = "SELECT * from [Person].[Person]"
data = pandas.read_sql(sql,conn)
data
# Out:
#        BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 0                     1         EM      False  None       Ken          J
# 1                     2         EM      False  None     Terri        Lee
# 2                     3         EM      False  None   Roberto       None
# 3                     4         EM      False  None       Rob       None
# 4                     5         EM      False   Ms.      Gail          A
# ...                 ...        ...        ...   ...       ...        ...
# 19967             20773         IN      False  None   Crystal       None
# 19968             20774         IN      False  None  Isabella          F
# 19969             20775         IN      False  None   Crystal          S
# 19970             20776         IN      False  None   Crystal       None
# 19971             20777         IN      False  None   Crystal       None
#
#          LastName Suffix  EmailPromotion AdditionalContactInfo  \
# ...

# %%
import pandas
sql = "SELECT * from [dbo].[titanic2022]"
data = pandas.read_sql(sql,conn2)
data
# Out:
#      Survived  Pclass                                               Name  \
# 0       False       3                            Braund, Mr. Owen Harris
# 1        True       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2        True       3                             Heikkinen, Miss. Laina
# 3        True       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       False       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886     False       2                              Montvila, Rev. Juozas
# 887      True       1                       Graham, Miss. Margaret Edith
# 888     False       3           Johnston, Miss. Catherine Helen Carrie""
# 889      True       1                              Behr, Mr. Karl Howell
# 890     False       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket       Fare Cabin Embarked
# ...
